# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

import utils_03 as utils

# %load_ext autoreload
# %autoreload 2

# %%
# %%html
# <style>
# table { font-family: monospace; }
# </style>
# Out:
# <style>
# table { font-family: monospace; }
# </style>

# %% [markdown]
# ## 01 Data Loading and Inspection

# %%
bn = utils.BabyNames()

# %%
bn.data.head()
# Out:
#         name sex  births  year
# 0       Mary   F    7065  1880
# 1       Anna   F    2604  1880
# 2       Emma   F    2003  1880
# 3  Elizabeth   F    1939  1880
# 4     Minnie   F    1746  1880

# %%
bn.data.shape
# Out:
# (1690784, 4)

# %% [markdown]
# ## 02 Total births by sex and year

# %%
bn = utils.BabyNames()

# %%
bn.plot_total_births(method='pd')

# %%
bn.plot_total_births(method='sns')

# %% [markdown]
# ## 03 Fraction of babies given each name relative to the total number of births

# %%
bn = utils.BabyNames()

# %%
bn.names_with_prop.head()
# Out:
#         name sex  births  year      prop
# 0       Mary   F    7065  1880  0.077643
# 1       Anna   F    2604  1880  0.028618
# 2       Emma   F    2003  1880  0.022013
# 3  Elizabeth   F    1939  1880  0.021309
# 4     Minnie   F    1746  1880  0.019188

# %% [markdown]
# ## 04 Top 1,000 names for each sex/year combination

# %%
bn = utils.BabyNames()
bn.top1000.head()
# Out:
#         name sex  births  year      prop
# 0       Mary   F    7065  1880  0.077643
# 1       Anna   F    2604  1880  0.028618
# 2       Emma   F    2003  1880  0.022013
# 3  Elizabeth   F    1939  1880  0.021309
# 4     Minnie   F    1746  1880  0.019188

# %% [markdown]
# ## 05 Analyzing Naming Trends

# %% [markdown]
# ### 01 Top names by year and sex in top 1000 names

# %%
# Plot top names
names = ['John', 'Harry', 'Mary', 'Marilyn']
bn.plot_top_names(names=names)

# %% [markdown]
# ### 02 Proportion of births represented by the top 1,000 most popular names

# %%
# Measuring the increase in naming diversity
# Proportion of births represented by the top 1,000 most popular names
bn.plot_prop(method='pd')

# %%
bn.plot_prop(method='sns')

# %% [markdown]
# ### 03 Number of distinct names, taken in order of popularity from highest to lowest, in the top 50% of births

# %%
bn = utils.BabyNames()

# %%
diversity = bn.get_diversity()
diversity.head()
# Out:
# sex    F   M
# year
# 1880  38  14
# 1881  38  14
# 1882  38  15
# 1883  39  15
# 1884  39  16

# %%
bn.plot_diversity()

# %% [markdown]
# ### 04 The "last letter" revolution

# %%
bn = utils.BabyNames()

# %%
bn.plot_last_letter(sex=bn.M)

# %%
bn.plot_last_letter(sex=bn.F)

# %%
bn.plot_last_letter(type='letters', sex=bn.M)
